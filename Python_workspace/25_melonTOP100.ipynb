# %%
import warnings
warnings.filterwarnings(action='ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
targetSite = 'https://www.melon.com/chart/index.htm'
request = requests.get(targetSite)
#406(허용되지 않음):요청한 페이지가 요청한 콘텐츠 특성으로 응답할 수 없다.
#print(request)

# %%
targetSite = 'https://www.melon.com/chart/index.htm'
header = {'User-agent':'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
request = requests.get(targetSite, headers=header)
print(request)
# Out:
# <Response [200]>

# %%
html = request.text
soup = BeautifulSoup(html, 'html.parser')

# %%
#노래 제목 크롤링
titles = soup.findAll('div', {'class':'ellipsis rank01'})
#print(titles)

for i in range(len(titles)):
    print('{0:3d}위 {1}'.format(i+1, titles[i].text.strip()))
# Out:
#   1위 STAY
#   2위 신호등
#   3위 Next Level
#   4위 바라만 본다
#   5위 Queendom
#   6위 낙하 (with 아이유)
#   7위 Permission to Dance
#   8위 Weekend
#   9위 OHAYO MY NIGHT
#  10위 DUMB DUMB
#  11위 Butter
#  12위 좋아좋아
#  13위 헤픈 우연
#  14위 Peaches (Feat. Daniel Caesar & Giveon)
#  15위 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
#  16위 Bad Habits
#  17위 Dynamite
#  18위 비와 당신
#  19위 Dun Dun Dance
#  20위 롤린 (Rollin')
#  21위 비가 오는 날엔 (2021)
#  22위 이제 나만 믿어요
#  23위 라일락
#  24위 다정히 내 이름을 부르면
#  25위 Celebrity
#  26위 고백
#  27위 치맛바람 (Chi Mat Ba Ram)
#  28위 하루만 더
#  29위 Alcohol-Free
#  30위 ASAP
#  31위 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
#  32위 안녕 (Hello)
#  33위 Savage Love (Laxed - Siren Beat) (BTS Remix)
#  34위 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  35위 운전만해 (We Ride)
#  36위 밝게 빛나는 별이 되어 비춰줄게
#  37위 가을 우체국 앞에서
#  38위 별빛 같은 나의 사랑아
#  39위 내 손을 잡아
#  40위 여전히 아름다운지
#  41위 나를 아는 사람
#  42위 멜로디
#  43위 봄날
#  44위 Off My Face
#  45위 밤하늘의 별을(2020)
#  46위 HERO
#  47위 상상더하기
#  48위 Lovesick Girls
#  49위 Timeless
#  50위 그대라는 사치
#  51위 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  52위 Life Goes On
#  53위 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  54위 다시 사랑한다면 (김필 Ver.)
#  55위 추억은 만남보다 이별에 남아
#  56위 아로하
#  57위 끝사랑
#  58위 어푸 (Ah puh)
#  59위 Bk Love
#  60위 Blueming
#  61위 잠이 오질 않네요
#  62위 잊었니
#  63위 상상더하기
#  64위 Dolphin
#  65위 에잇(Prod.&Feat. SUGA of BTS)
#  66위 취기를 빌려 (취향저격 그녀 X 산들)
#  67위 그날에 나는 맘이 편했을까
#  68위 2002
#  69위 모든 날, 모든 순간 (Every day, Every Moment)
#  70위 가까운 듯 먼 그대여
#  71위 LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
#  72위 METEOR
#  73위 고백
#  74위 12:45 (Stripped)
#  75위 이젠 잊기로 해요 (Drama Ver.)
#  76위 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  77위 라라라
#  78위 미워요
#  79위 오래된 노래
#  80위 담아 갈게
#  81위 너의 번호를 누르고 (Prod. 영화처럼)
#  82위 사랑의 아픔 딛고
#  83위 슈퍼스타
#  84위 VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
#  85위 계단말고 엘리베이터
#  86위 허리춤
#  87위 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
#  88위 어떻게 지내 (Prod. By VAN.C)
#  89위 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
#  90위 사실 나는 (Feat.전건호)
#  91위 고백
#  92위 Memories
#  93위 Coin
#  94위 회상
#  95위 넌 좋은 사람
#  96위 On The Ground
#  97위 목로주점
#  98위 사진을 보다가
#  99위 나는 너 좋아
# 100위 내사람

# %%
#아티스트 크롤링
artists = soup.findAll('span', {'class':'checkEllipsis'})

for i in range(len(artists)):
    print('{0:3d}위 {1}'.format(i+1, artists[i].text.strip().split('\n')[0]))
# Out:
#   1위 The Kid LAROI, Justin Bieber
#   2위 이무진
#   3위 aespa
#   4위 MSG워너비(M.O.M)
#   5위 Red Velvet (레드벨벳)
#   6위 AKMU (악뮤)
#   7위 방탄소년단
#   8위 태연 (TAEYEON)
#   9위 디핵 (D-Hack), PATEKO (파테코)
#  10위 전소미
#  11위 방탄소년단
#  12위 조정석
#  13위 헤이즈 (Heize)
#  14위 Justin Bieber
#  15위 케이윌
#  16위 Ed Sheeran
#  17위 방탄소년단
#  18위 이무진
#  19위 오마이걸 (OH MY GIRL)
#  20위 브레이브걸스
#  21위 헤이즈 (Heize)
#  22위 임영웅
#  23위 아이유
#  24위 경서예지, 전건호
#  25위 아이유
#  26위 멜로망스
#  27위 브레이브걸스
#  28위 빅마마
#  29위 TWICE (트와이스)
#  30위 STAYC(스테이씨)
#  31위 호미들
#  32위 조이 (JOY)
#  33위 Jawsh 685, Jason Derulo, 방탄소년단
#  34위 방탄소년단
#  35위 브레이브걸스
#  36위 송이한
#  37위 김대명
#  38위 임영웅
#  39위 아이유
#  40위 세븐틴
#  41위 MSG워너비(정상동기)
#  42위 ASH ISLAND
#  43위 방탄소년단
#  44위 Justin Bieber
#  45위 경서
#  46위 임영웅
#  47위 라붐 (LABOUM)
#  48위 BLACKPINK
#  49위 SG 워너비
#  50위 임영웅
#  51위 에픽하이 (EPIK HIGH)
#  52위 방탄소년단
#  53위 AKMU (악뮤)
#  54위 임영웅
#  55위 정동하
#  56위 조정석
#  57위 임영웅
#  58위 아이유
#  59위 임영웅
#  60위 아이유
#  61위 장범준
#  62위 임영웅
#  63위 MSG워너비 TOP 8 (별루지, 김정수, 강창모, 정기석, 이동휘, 이상이, 박재정, 원슈타인)
#  64위 오마이걸 (OH MY GIRL)
#  65위 아이유
#  66위 산들
#  67위 이예준
#  68위 Anne-Marie
#  69위 폴킴
#  70위 카더가든
#  71위 양요섭, 정은지
#  72위 창모 (CHANGMO)
#  73위 10CM
#  74위 Etham
#  75위 미도와 파라솔
#  76위 장범준
#  77위 SG 워너비
#  78위 임영웅
#  79위 스탠딩 에그
#  80위 이무진
#  81위 #안녕
#  82위 임영웅
#  83위 미도와 파라솔
#  84위 미란이 (Mirani), 먼치맨(MUNCHMAN), Khundi Panda, 머쉬베놈 (MUSHVENOM)
#  85위 임영웅
#  86위 오반 (OVAN)
#  87위 적재
#  88위 오반 (OVAN)
#  89위 마크툽 (MAKTUB)
#  90위 경서예지
#  91위 장범준
#  92위 Maroon 5
#  93위 아이유
#  94위 정경호
#  95위 SG 워너비
#  96위 로제 (ROSÉ)
#  97위 임영웅
#  98위 다비치
#  99위 장범준
# 100위 SG 워너비

# %%
#크롤링한 결과를 텍스트 파일로 저장한다.
#file = open('melonTOP100.txt', 'w')
#위의 문장처럼 실행했는데 에러가 발생하면 아래와 같이 open()함수를 수정한다.
file = open('melonTOP100.txt', 'w', -1, 'UTF-8')
file.write('{} 현재 melon 뮤직 실시간 TOP 100\n'.format(dt.now()))
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title =  titles[i].text.strip().split('\n')[0]
    file.write('{0:3d}위 {1} - {2}\n'.format(i + 1, artist, title))
file.close()
print('melonTOP100.txt 파일로 쓰기 완료')
# Out:
# melonTOP100.txt 파일로 쓰기 완료

# %%
#텍스트 파일에 저장된 데이터를 읽어서 화면에 출력한다.
try:
    file = open('melonTOP100.txt', 'r', -1, 'UTF-8')
    lines = file.readlines()
    for line in lines:
        print(line.strip())
    file.close()
    print('melonTOP100.txt 파일에서 읽기 완료')
except FileNotFoundError:
    print('디스크에 melonTOP100.txt 파일이 없습니다.')
# Out:
# 2021-09-01 20:39:51.752868 현재 melon 뮤직 실시간 TOP 100
# 1위 The Kid LAROI, Justin Bieber - STAY
# 2위 이무진 - 신호등
# 3위 aespa - Next Level
# 4위 MSG워너비(M.O.M) - 바라만 본다
# 5위 Red Velvet (레드벨벳) - Queendom
# 6위 AKMU (악뮤) - 낙하 (with 아이유)
# 7위 방탄소년단 - Permission to Dance
# 8위 태연 (TAEYEON) - Weekend
# 9위 디핵 (D-Hack), PATEKO (파테코) - OHAYO MY NIGHT
# 10위 전소미 - DUMB DUMB
# 11위 방탄소년단 - Butter
# 12위 조정석 - 좋아좋아
# 13위 헤이즈 (Heize) - 헤픈 우연
# 14위 Justin Bieber - Peaches (Feat. Daniel Caesar & Giveon)
# 15위 케이윌 - 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
# 16위 Ed Sheeran - Bad Habits
# 17위 방탄소년단 - Dynamite
# 18위 이무진 - 비와 당신
# 19위 오마이걸 (OH MY GIRL) - Dun Dun Dance
# 20위 브레이브걸스 - 롤린 (Rollin')
# 21위 헤이즈 (Heize) - 비가 오는 날엔 (2021)
# 22위 임영웅 - 이제 나만 믿어요
# 23위 아이유 - 라일락
# 24위 경서예지, 전건호 - 다정히 내 이름을 부르면
# 25위 아이유 - Celebrity
# 26위 멜로망스 - 고백
# 27위 브레이브걸스 - 치맛바람 (Chi Mat Ba Ram)
# 28위 빅마마 - 하루만 더
# 29위 TWICE (트와이스) - Alcohol-Free
# 30위 STAYC(스테이씨) - ASAP
# 31위 호미들 - 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
# 32위 조이 (JOY) - 안녕 (Hello)
# 33위 Jawsh 685, Jason Derulo, 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
# 34위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 35위 브레이브걸스 - 운전만해 (We Ride)
# 36위 송이한 - 밝게 빛나는 별이 되어 비춰줄게
# 37위 김대명 - 가을 우체국 앞에서
# 38위 임영웅 - 별빛 같은 나의 사랑아
# 39위 아이유 - 내 손을 잡아
# 40위 세븐틴 - 여전히 아름다운지
# 41위 MSG워너비(정상동기) - 나를 아는 사람
# 42위 ASH ISLAND - 멜로디
# 43위 방탄소년단 - 봄날
# 44위 Justin Bieber - Off My Face
# 45위 경서 - 밤하늘의 별을(2020)
# 46위 임영웅 - HERO
# 47위 라붐 (LABOUM) - 상상더하기
# 48위 BLACKPINK - Lovesick Girls
# 49위 SG 워너비 - Timeless
# 50위 임영웅 - 그대라는 사치
# 51위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
# 52위 방탄소년단 - Life Goes On
# 53위 AKMU (악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 54위 임영웅 - 다시 사랑한다면 (김필 Ver.)
# 55위 정동하 - 추억은 만남보다 이별에 남아
# 56위 조정석 - 아로하
# 57위 임영웅 - 끝사랑
# 58위 아이유 - 어푸 (Ah puh)
# 59위 임영웅 - Bk Love
# 60위 아이유 - Blueming
# 61위 장범준 - 잠이 오질 않네요
# 62위 임영웅 - 잊었니
# 63위 MSG워너비 TOP 8 (별루지, 김정수, 강창모, 정기석, 이동휘, 이상이, 박재정, 원슈타인) - 상상더하기
# 64위 오마이걸 (OH MY GIRL) - Dolphin
# 65위 아이유 - 에잇(Prod.&Feat. SUGA of BTS)
# 66위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
# 67위 이예준 - 그날에 나는 맘이 편했을까
# 68위 Anne-Marie - 2002
# 69위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
# 70위 카더가든 - 가까운 듯 먼 그대여
# 71위 양요섭, 정은지 - LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
# 72위 창모 (CHANGMO) - METEOR
# 73위 10CM - 고백
# 74위 Etham - 12:45 (Stripped)
# 75위 미도와 파라솔 - 이젠 잊기로 해요 (Drama Ver.)
# 76위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 77위 SG 워너비 - 라라라
# 78위 임영웅 - 미워요
# 79위 스탠딩 에그 - 오래된 노래
# 80위 이무진 - 담아 갈게
# 81위 #안녕 - 너의 번호를 누르고 (Prod. 영화처럼)
# 82위 임영웅 - 사랑의 아픔 딛고
# 83위 미도와 파라솔 - 슈퍼스타
# 84위 미란이 (Mirani), 먼치맨(MUNCHMAN), Khundi Panda, 머쉬베놈 (MUSHVENOM) - VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
# 85위 임영웅 - 계단말고 엘리베이터
# 86위 오반 (OVAN) - 허리춤
# 87위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 88위 오반 (OVAN) - 어떻게 지내 (Prod. By VAN.C)
# 89위 마크툽 (MAKTUB) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 90위 경서예지 - 사실 나는 (Feat.전건호)
# 91위 장범준 - 고백
# 92위 Maroon 5 - Memories
# 93위 아이유 - Coin
# 94위 정경호 - 회상
# 95위 SG 워너비 - 넌 좋은 사람
# 96위 로제 (ROSÉ) - On The Ground
# 97위 임영웅 - 목로주점
# 98위 다비치 - 사진을 보다가
# 99위 장범준 - 나는 너 좋아
# 100위 SG 워너비 - 내사람
# melonTOP100.txt 파일에서 읽기 완료
