# %%
import warnings
warnings.filterwarnings(action='ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
print(dt.now())
# Out:
# 2021-09-01 20:53:23.690371

# %%
targetSite = 'https://music.bugs.co.kr/chart'
request = requests.get(targetSite)
#print(request)
html = request.text
soup = BeautifulSoup(html, 'html.parser')
#print(soup)

# %%
#노래 제목 크롤링
titles = soup.findAll('p', {'class':'title'})
#print(titles)
#print(len(titles))

for i in range(len(titles)):
    #print('{0:3d}위 {1}'.format(i+1, titles[i].text.strip()))
    #print(titles[i].text.split('\n')[1])
    print('{0:3d}위 {1}'.format(i+1, titles[i].text.strip().split('\n')[0]))
# Out:
#   1위 고백
#   2위 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
#   3위 STAY
#   4위 Talk & Talk
#   5위 Queendom
#   6위 DUMB DUMB
#   7위 신호등
#   8위 Hate that... (Feat. 태연)
#   9위 가까운 듯 먼 그대여
#  10위 오늘은 가지마 (2021)
#  11위 Next Level
#  12위 낙하 (with 아이유)
#  13위 나인가요
#  14위 비가 오는 날엔 (2021)
#  15위 Weekend
#  16위 OHAYO MY NIGHT
#  17위 Permission to Dance
#  18위 별이 빛나는 밤에
#  19위 Butter
#  20위 WE GO
#  21위 이대로만 (Feat. 죠지)
#  22위 좋아좋아
#  23위 바라만 본다
#  24위 눈물을 훔친다 (금혼령 X 김종국)
#  25위 Bad Habits
#  26위 It's My Life
#  27위 ONLY
#  28위 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  29위 여전히 아름다운지
#  30위 고백
#  31위 안녕 (Hello)
#  32위 Peaches (feat. Daniel Caesar, Giveon)
#  33위 Dun Dun Dance
#  34위 사진을 보다가
#  35위 고백
#  36위 Alcohol-Free
#  37위 ASAP
#  38위 헤픈 우연
#  39위 제자리 걸음
#  40위 Dynamite
#  41위 비와 당신
#  42위 다정히 내 이름을 부르면
#  43위 하루만 더
#  44위 라일락
#  45위 술버릇 (운전만해 그후)
#  46위 회상
#  47위 Off My Face
#  48위 Celebrity
#  49위 뚫고 지나가요
#  50위 벌써 일년 (Drama Ver.)
#  51위 롤린 (Rollin')
#  52위 You can't sit with us
#  53위 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
#  54위 도망가자 (Run With Me)
#  55위 Kiss Me More (feat. SZA)
#  56위 Black Mamba
#  57위 I'm Gonna Love You (Feat. 원슈타인)
#  58위 이젠 잊기로 해요 (Drama Ver.)
#  59위 Loving You Girl (feat. Hkeem)
#  60위 Find The Way
#  61위 가을 우체국 앞에서
#  62위 Lovesick Girls
#  63위 치맛바람 (Chi Mat Ba Ram)
#  64위 슈퍼스타
#  65위 나는 너 좋아
#  66위 Outsider
#  67위 운전만해 (We Ride)
#  68위 상상더하기
#  69위 FUN!
#  70위 Feel Good (SECRET CODE)
#  71위 Leave Before You Love Me
#  72위 은근히 낯가려요 (feat. RAVI)
#  73위 넌 좋은 사람
#  74위 에잇(Prod.&Feat. SUGA of BTS)
#  75위 전쟁터 (with 이선희)
#  76위 Timeless
#  77위 너에게
#  78위 밤이 되니까
#  79위 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  80위 내 손을 잡아
#  81위 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  82위 어푸 (Ah puh)
#  83위 추적이는 여름 비가 되어
#  84위 Blueming
#  85위 Leave The Door Open
#  86위 사랑하니까 (2021)
#  87위 Dolphin
#  88위 Savage Love (Laxed - Siren Beat) (BTS Remix)
#  89위 parachute
#  90위 보고 싶단 말이야
#  91위 나를 아는 사람
#  92위 LOVE BOMB
#  93위 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  94위 THRILL RIDE
#  95위 Life Goes On
#  96위 야화
#  97위 Pose
#  98위 잠이 오질 않네요
#  99위 째깍 째깍 째깍 (with Beenzino)
# 100위 외딴섬 로맨틱

# %%
#아티스트 크롤링
artists = soup.findAll('p', {'class':'artist'})

for i in range(len(artists)):
    print('{0:3d}위 {1}'.format(i+1, artists[i].text.strip().split('\n')[0]))
# Out:
#   1위 멜로망스(MeloMance)
#   2위 케이윌
#   3위 The Kid LAROI
#   4위 프로미스나인
#   5위 Red Velvet (레드벨벳)
#   6위 전소미
#   7위 이무진
#   8위 키 (KEY)
#   9위 카더가든
#  10위 환희
#  11위 aespa
#  12위 AKMU(악뮤)
#  13위 백현(BAEKHYUN)
#  14위 헤이즈(Heize)
#  15위 태연 (TAEYEON)
#  16위 디핵(D-Hack)
#  17위 방탄소년단
#  18위 규현 (KYUHYUN)
#  19위 방탄소년단
#  20위 프로미스나인
#  21위 로꼬
#  22위 조정석
#  23위 MSG워너비(M.O.M)
#  24위 김종국
#  25위 Ed Sheeran(에드 시런)
#  26위 윤미래
#  27위 이하이
#  28위 에픽하이 (EPIK HIGH)
#  29위 세븐틴(SEVENTEEN)
#  30위 10CM
#  31위 조이 (JOY)
#  32위 Justin Bieber(저스틴 비버)
#  33위 오마이걸(OH MY GIRL)
#  34위 다비치
#  35위 장범준
#  36위 TWICE (트와이스)
#  37위 STAYC(스테이씨)
#  38위 헤이즈(Heize)
#  39위 V.O.S.
#  40위 방탄소년단
#  41위 이무진
#  42위 경서예지
#  43위 빅마마(Big Mama)
#  44위 아이유(IU)
#  45위 브레이브걸스(Brave Girls)
#  46위 정경호
#  47위 Justin Bieber(저스틴 비버)
#  48위 아이유(IU)
#  49위 DAY6 (Even of Day)
#  50위 미도와 파라솔
#  51위 브레이브걸스(Brave Girls)
#  52위 선미
#  53위 호미들
#  54위 선우정아(Sunwoojunga)
#  55위 Doja Cat(도자 캣)
#  56위 aespa
#  57위 디오 (D.O.)
#  58위 미도와 파라솔
#  59위 Peder Elias
#  60위 정인
#  61위 김대명
#  62위 BLACKPINK
#  63위 브레이브걸스(Brave Girls)
#  64위 미도와 파라솔
#  65위 장범준
#  66위 비투비
#  67위 브레이브걸스(Brave Girls)
#  68위 라붐(LABOUM)
#  69위 프로미스나인
#  70위 프로미스나인
#  71위 Marshmello(마시멜로)
#  72위 부끄뚱
#  73위 SG워너비
#  74위 아이유(IU)
#  75위 AKMU(악뮤)
#  76위 SG워너비
#  77위 유연석
#  78위 원슈타인
#  79위 AKMU(악뮤)
#  80위 아이유(IU)
#  81위 장범준
#  82위 아이유(IU)
#  83위 장범준
#  84위 아이유(IU)
#  85위 Bruno Mars(브루노 마스)
#  86위 이보람 (씨야)
#  87위 오마이걸(OH MY GIRL)
#  88위 Jawsh 685
#  89위 John K
#  90위 펀치 (Punch)
#  91위 MSG워너비(정상동기)
#  92위 프로미스나인
#  93위 방탄소년단
#  94위 더보이즈(THE BOYZ)
#  95위 방탄소년단
#  96위 안예은
#  97위 Red Velvet (레드벨벳)
#  98위 장범준
#  99위 AKMU(악뮤)
# 100위 잔나비

# %%
#크롤링한 결과를 텍스트 파일로 저장한다.
#file = open('bugsTOP100.txt', 'w')
#위의 문장처럼 실행했는데 에러가 발생하면 아래와 같이 open()함수를 수정한다.
file = open('bugsTOP100.txt', 'w', -1, 'UTF-8')
file.write('{} 현재 bugs 뮤직 실시간 TOP 100\n'.format(dt.now()))
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title =  titles[i].text.strip().split('\n')[0]
    file.write('{0:3d}위 {1} - {2}\n'.format(i + 1, artist, title))
file.close()
print('bugsTOP100.txt 파일로 쓰기 완료')
# Out:
# bugsTOP100.txt 파일로 쓰기 완료

# %%
#텍스트 파일에 저장된 데이터를 읽어서 화면에 출력한다.
try:
    file = open('bugsTOP100.txt', 'r', -1, 'UTF-8')
    lines = file.readlines()
    for line in lines:
        print(line.strip())
    file.close()
    print('bugsTOP100.txt 파일에서 읽기 완료')
except FileNotFoundError:
    print('디스크에 melonTOP100.txt 파일이 없습니다.')
# Out:
# 2021-09-01 20:53:32.611260 현재 bugs 뮤직 실시간 TOP 100
# 1위 멜로망스(MeloMance) - 고백
# 2위 케이윌 - 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
# 3위 The Kid LAROI - STAY
# 4위 프로미스나인 - Talk & Talk
# 5위 Red Velvet (레드벨벳) - Queendom
# 6위 전소미 - DUMB DUMB
# 7위 이무진 - 신호등
# 8위 키 (KEY) - Hate that... (Feat. 태연)
# 9위 카더가든 - 가까운 듯 먼 그대여
# 10위 환희 - 오늘은 가지마 (2021)
# 11위 aespa - Next Level
# 12위 AKMU(악뮤) - 낙하 (with 아이유)
# 13위 백현(BAEKHYUN) - 나인가요
# 14위 헤이즈(Heize) - 비가 오는 날엔 (2021)
# 15위 태연 (TAEYEON) - Weekend
# 16위 디핵(D-Hack) - OHAYO MY NIGHT
# 17위 방탄소년단 - Permission to Dance
# 18위 규현 (KYUHYUN) - 별이 빛나는 밤에
# 19위 방탄소년단 - Butter
# 20위 프로미스나인 - WE GO
# 21위 로꼬 - 이대로만 (Feat. 죠지)
# 22위 조정석 - 좋아좋아
# 23위 MSG워너비(M.O.M) - 바라만 본다
# 24위 김종국 - 눈물을 훔친다 (금혼령 X 김종국)
# 25위 Ed Sheeran(에드 시런) - Bad Habits
# 26위 윤미래 - It's My Life
# 27위 이하이 - ONLY
# 28위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
# 29위 세븐틴(SEVENTEEN) - 여전히 아름다운지
# 30위 10CM - 고백
# 31위 조이 (JOY) - 안녕 (Hello)
# 32위 Justin Bieber(저스틴 비버) - Peaches (feat. Daniel Caesar, Giveon)
# 33위 오마이걸(OH MY GIRL) - Dun Dun Dance
# 34위 다비치 - 사진을 보다가
# 35위 장범준 - 고백
# 36위 TWICE (트와이스) - Alcohol-Free
# 37위 STAYC(스테이씨) - ASAP
# 38위 헤이즈(Heize) - 헤픈 우연
# 39위 V.O.S. - 제자리 걸음
# 40위 방탄소년단 - Dynamite
# 41위 이무진 - 비와 당신
# 42위 경서예지 - 다정히 내 이름을 부르면
# 43위 빅마마(Big Mama) - 하루만 더
# 44위 아이유(IU) - 라일락
# 45위 브레이브걸스(Brave Girls) - 술버릇 (운전만해 그후)
# 46위 정경호 - 회상
# 47위 Justin Bieber(저스틴 비버) - Off My Face
# 48위 아이유(IU) - Celebrity
# 49위 DAY6 (Even of Day) - 뚫고 지나가요
# 50위 미도와 파라솔 - 벌써 일년 (Drama Ver.)
# 51위 브레이브걸스(Brave Girls) - 롤린 (Rollin')
# 52위 선미 - You can't sit with us
# 53위 호미들 - 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
# 54위 선우정아(Sunwoojunga) - 도망가자 (Run With Me)
# 55위 Doja Cat(도자 캣) - Kiss Me More (feat. SZA)
# 56위 aespa - Black Mamba
# 57위 디오 (D.O.) - I'm Gonna Love You (Feat. 원슈타인)
# 58위 미도와 파라솔 - 이젠 잊기로 해요 (Drama Ver.)
# 59위 Peder Elias - Loving You Girl (feat. Hkeem)
# 60위 정인 - Find The Way
# 61위 김대명 - 가을 우체국 앞에서
# 62위 BLACKPINK - Lovesick Girls
# 63위 브레이브걸스(Brave Girls) - 치맛바람 (Chi Mat Ba Ram)
# 64위 미도와 파라솔 - 슈퍼스타
# 65위 장범준 - 나는 너 좋아
# 66위 비투비 - Outsider
# 67위 브레이브걸스(Brave Girls) - 운전만해 (We Ride)
# 68위 라붐(LABOUM) - 상상더하기
# 69위 프로미스나인 - FUN!
# 70위 프로미스나인 - Feel Good (SECRET CODE)
# 71위 Marshmello(마시멜로) - Leave Before You Love Me
# 72위 부끄뚱 - 은근히 낯가려요 (feat. RAVI)
# 73위 SG워너비 - 넌 좋은 사람
# 74위 아이유(IU) - 에잇(Prod.&Feat. SUGA of BTS)
# 75위 AKMU(악뮤) - 전쟁터 (with 이선희)
# 76위 SG워너비 - Timeless
# 77위 유연석 - 너에게
# 78위 원슈타인 - 밤이 되니까
# 79위 AKMU(악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 80위 아이유(IU) - 내 손을 잡아
# 81위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 82위 아이유(IU) - 어푸 (Ah puh)
# 83위 장범준 - 추적이는 여름 비가 되어
# 84위 아이유(IU) - Blueming
# 85위 Bruno Mars(브루노 마스) - Leave The Door Open
# 86위 이보람 (씨야) - 사랑하니까 (2021)
# 87위 오마이걸(OH MY GIRL) - Dolphin
# 88위 Jawsh 685 - Savage Love (Laxed - Siren Beat) (BTS Remix)
# 89위 John K - parachute
# 90위 펀치 (Punch) - 보고 싶단 말이야
# 91위 MSG워너비(정상동기) - 나를 아는 사람
# 92위 프로미스나인 - LOVE BOMB
# 93위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 94위 더보이즈(THE BOYZ) - THRILL RIDE
# 95위 방탄소년단 - Life Goes On
# 96위 안예은 - 야화
# 97위 Red Velvet (레드벨벳) - Pose
# 98위 장범준 - 잠이 오질 않네요
# 99위 AKMU(악뮤) - 째깍 째깍 째깍 (with Beenzino)
# 100위 잔나비 - 외딴섬 로맨틱
# bugsTOP100.txt 파일에서 읽기 완료
