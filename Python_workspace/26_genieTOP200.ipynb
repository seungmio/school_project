# %%
import warnings
warnings.filterwarnings(action='ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
# 타겟 사이트 주소 만들기
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210901&hh=20&rtm=Y&pg=1 =>   1 ~  50
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210901&hh=20&rtm=Y&pg=2 =>  51 ~ 100
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210901&hh=20&rtm=Y&pg=3 => 101 ~ 150
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210901&hh=20&rtm=Y&pg=4 => 151 ~ 200
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210901&hh=20&rtm=Y&pg='
for i in range(1, 5):
    # targetSite = url + str(i)
    targetSite = '{}{}'.format(url, i)
    print(targetSite)
# Out:
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210901&hh=20&rtm=Y&pg=1
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210901&hh=20&rtm=Y&pg=2
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210901&hh=20&rtm=Y&pg=3
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210901&hh=20&rtm=Y&pg=4

# %%
# 노래 제목 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210901&hh=20&rtm=Y&pg='
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    # print(request)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')
    # print(soup)
    
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    # print(titles)
    # print(len(titles))
    
    for i in range(len(titles)):
        # print('{0:3d}위 {1}'.format(i + 1, titles[i].text.strip()))
        # print('{0:3d}위 {1}'.format(i + 1, titles[i].text.split('\n')[-1].strip()))
        print('{0:3d}위 {1}'.format(i + 1, titles[i].text.strip().split('\n')[0]))
# Out:
#   1위 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
#   2위 Stay
#   3위 신호등
#   4위 바라만 본다
#   5위 고백
#   6위 OHAYO MY NIGHT
#   7위 Queendom
#   8위 낙하 (With 아이유)
#   9위 Next Level
#  10위 Bad Habits
#  11위 Weekend
#  12위 좋아좋아
#  13위 Permission to Dance
#  14위 DUMB DUMB
#  15위 Butter
#  16위 Peaches (Feat. Daniel Caesar & Giveon)
#  17위 비와 당신
#  18위 헤픈 우연
#  19위 비가 오는 날엔 (2021)
#  20위 Dynamite
#  21위 다정히 내 이름을 부르면
#  22위 롤린 (Rollin')
#  23위 라일락
#  24위 하루만 더
#  25위 이제 나만 믿어요
#  26위 Dun Dun Dance
#  27위 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  28위 고백
#  29위 Celebrity
#  30위 치맛바람 (Chi Mat Ba Ram)
#  31위 Savage Love (Laxed - Siren Beat) (BTS Remix)
#  32위 사진을 보다가
#  33위 다시 사랑한다면 (김필 Ver.)
#  34위 별빛 같은 나의 사랑아
#  35위 Alcohol-Free
#  36위 내 손을 잡아
#  37위 가을 우체국 앞에서
#  38위 HERO
#  39위 운전만해 (We Ride)
#  40위 Off My Face
#  41위 At My Worst
#  42위 안녕 (Hello)
#  43위 여전히 아름다운지
#  44위 아로하
#  45위 Timeless
#  46위 사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)
#  47위 상상더하기
#  48위 2002
#  49위 ASAP
#  50위 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)

# %%
# 아트스트 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210901&hh=20&rtm=Y&pg='
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')

    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    # print(artists)
    # print(len(artists))
    
    for i in range(5, len(artists)):
        # print('{0:3d}위 {1}'.format(i - 4, artists[i].text.strip()))
        # print('{0:3d}위 {1}'.format(i - 4, artists[i].text.split('\n')[0]))
        print('{0:3d}위 {1}'.format(i - 4, artists[i].text.strip().split('\n')[0]))
# Out:
#   1위 케이윌 (K.Will)
#   2위 The Kid LAROI & Justin Bieber
#   3위 이무진
#   4위 MSG워너비 (M.O.M)
#   5위 멜로망스 (MeloMance)
#   6위 디핵 (D-Hack) & PATEKO
#   7위 Red Velvet (레드벨벳)
#   8위 AKMU (악뮤)
#   9위 aespa
#  10위 Ed Sheeran
#  11위 태연 (TAEYEON)
#  12위 조정석
#  13위 방탄소년단
#  14위 전소미
#  15위 방탄소년단
#  16위 Justin Bieber
#  17위 이무진
#  18위 헤이즈 (Heize)
#  19위 헤이즈 (Heize)
#  20위 방탄소년단
#  21위 경서예지 & 전건호
#  22위 브레이브걸스 (Brave girls)
#  23위 아이유 (IU)
#  24위 빅마마 (Big Mama)
#  25위 임영웅
#  26위 오마이걸 (OH MY GIRL)
#  27위 에픽하이 (EPIK HIGH)
#  28위 10CM
#  29위 아이유 (IU)
#  30위 브레이브걸스 (Brave girls)
#  31위 Jawsh 685 & Jason Derulo & 방탄소년단
#  32위 다비치
#  33위 임영웅
#  34위 임영웅
#  35위 TWICE (트와이스)
#  36위 아이유 (IU)
#  37위 김대명
#  38위 임영웅
#  39위 브레이브걸스 (Brave girls)
#  40위 Justin Bieber
#  41위 Pink Sweat$
#  42위 조이 (JOY)
#  43위 세븐틴 (SEVENTEEN)
#  44위 조정석
#  45위 SG워너비
#  46위 호미들
#  47위 라붐 (LABOUM)
#  48위 Anne-Marie
#  49위 STAYC (스테이씨)
#  50위 방탄소년단

# %%
# 크롤링한 데이터를 리스트에 저장한다.
genie = []
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210901&hh=20&rtm=Y&pg='
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 5):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')

    titles = soup.findAll('a', {'class': 'title ellipsis'})
    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    
    for j in range(50):
        genie.append(
            (artists[j + 5].text.strip().split('\n')[0], titles[j].text.strip().split('\n')[0])
        )
# print(len(genie))
print(genie)
# Out:
# [('케이윌 (K.Will)', '시간을 거슬러 (낮에 뜨는 달 X 케이윌)'), ('The Kid LAROI & Justin Bieber', 'Stay'), ('이무진', '신호등'), ('MSG워너비 (M.O.M)', '바라만 본다'), ('멜로망스 (MeloMance)', '고백'), ('디핵 (D-Hack) & PATEKO', 'OHAYO MY NIGHT'), ('Red Velvet (레드벨벳)', 'Queendom'), ('AKMU (악뮤)', '낙하 (With 아이유)'), ('aespa', 'Next Level'), ('Ed Sheeran', 'Bad Habits'), ('태연 (TAEYEON)', 'Weekend'), ('조정석', '좋아좋아'), ('방탄소년단', 'Permission to Dance'), ('전소미', 'DUMB DUMB'), ('방탄소년단', 'Butter'), ('Justin Bieber', 'Peaches (Feat. Daniel Caesar & Giveon)'), ('이무진', '비와 당신'), ('헤이즈 (Heize)', '헤픈 우연'), ('헤이즈 (Heize)', '비가 오는 날엔 (2021)'), ('방탄소년단', 'Dynamite'), ('경서예지 & 전건호', '다정히 내 이름을 부르면'), ('브레이브걸스 (Brave girls)', "롤린 (Rollin')"), ('아이유 (IU)', '라일락'), ('빅마마 (Big Mama)', '하루만 더'), ('임영웅', '이제 나만 믿어요'), ('오마이걸 (OH MY GIRL)', 'Dun Dun Dance'), ('에픽하이 (EPIK HIGH)', '비 오는 날 듣기 좋은 노래 (Feat. Colde)'), ('10CM', '고백'), ('아이유 (IU)', 'Celebrity'), ('브레이브걸스 (Brave girls)', '치맛바람 (Chi Mat Ba Ram)'), ('Jawsh 685 & Jason Derulo & 방탄소년단', 'Savage Love (Laxed - Siren Beat) (BTS Remix)'), ('다비치', '사진을 보다가'), ('임영웅', '다시 사랑한다면 (김필 Ver.)'), ('임영웅', '별빛 같은 나의 사랑아'), ('TWICE (트와이스)', 'Alcohol-Free'), ('아이유 (IU)', '내 손을 잡아'), ('김대명', '가을 우체국 앞에서'), ('임영웅', 'HERO'), ('브레이브걸스 (Brave girls)', '운전만해 (We Ride)'), ('Justin Bieber', 'Off My Face'), ('Pink Sweat$', 'At My Worst'), ('조이 (JOY)', '안녕 (Hello)'), ('세븐틴 (SEVENTEEN)', '여전히 아름다운지'), ('조정석', '아로하'), ('SG워너비', 'Timeless'), ('호미들', '사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)'), ('라붐 (LABOUM)', '상상더하기'), ('Anne-Marie', '2002'), ('STAYC (스테이씨)', 'ASAP'), ('방탄소년단', '작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)'), ('장범준', '추적이는 여름 비가 되어'), ('임영웅', '그대라는 사치'), ('MSG워너비 (정상동기)', '나를 아는 사람'), ('etham', '12 : 45 (Stripped)'), ('임영웅', '끝사랑'), ('송이한', '밝게 빛나는 별이 되어 비춰줄게'), ('임영웅', 'Bk Love'), ('Stray Kids (스트레이 키즈)', '소리꾼'), ('장범준', '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야'), ('아이유 (IU)', 'Blueming'), ('미도와 파라솔', '이젠 잊기로 해요 (Drama Ver.)'), ('폴킴', '모든 날, 모든 순간 (Every day, Every Moment)'), ('아이유 (IU)', '어푸 (Ah puh)'), ('아이유 (IU)', '에잇 (Prod. & Feat. SUGA of BTS)'), ('임영웅', '잊었니'), ('방탄소년단', 'Life Goes On'), ('김종국', '눈물을 훔친다 (금혼령 X 김종국)'), ('방탄소년단', '봄날'), ('Doja Cat', 'Kiss Me More (Feat. SZA)'), ('MSG워너비', '상상더하기'), ('양요섭 & 정은지', 'LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)'), ('경서', '밤하늘의 별을 (2020)'), ('ASH ISLAND', '멜로디'), ('환희', '오늘은 가지마 (2021)'), ('임영웅', '미워요'), ('규현 (KYUHYUN)', '별이 빛나는 밤에'), ('AKMU (악뮤)', '어떻게 이별까지 사랑하겠어, 널 사랑하는 거지'), ('미도와 파라솔', '슈퍼스타'), ('Bruno Mars & Anderson .Paak & Silk Sonic', 'Leave The Door Open'), ('임영웅', '계단말고 엘리베이터'), ('BLACKPINK', 'Lovesick Girls'), ('창모 (CHANGMO)', 'METEOR'), ('임영웅', '사랑의 아픔 딛고'), ('장범준', '나는 너 좋아'), ('임영웅', '목로주점'), ('장범준', '잠이 오질 않네요'), ('장범준', '고백'), ('John K', 'parachute'), ('Standing Egg (스탠딩 에그)', '오래된 노래'), ('오마이걸 (OH MY GIRL)', 'Dolphin'), ('Maroon 5', 'Memories'), ('전미도', '사랑하게 될 줄 알았어'), ('산들', '취기를 빌려 (취향저격 그녀 X 산들)'), ('정경호', '회상'), ('미란이 (Mirani) & 먼치맨 (MUNCHMAN) & Khundi Panda & 머쉬베놈 (MUSHVENOM)', 'VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)'), ('로꼬 & 이성경', '러브 (Prod. by 로코베리)'), ('Tones And I', 'Dance Monkey'), ('미도와 파라솔', '벌써 일년 (Drama Ver.)'), ('경서예지', '은하수를 닮은 너에게 (Feat. 몰리디)'), ('헤이즈 (Heize)', '비도 오고 그래서 (Feat. 신용재)'), ('원슈타인', '밤이 되니까'), ('아이유 (IU)', 'Coin'), ('마크툽 (Maktub)', '오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)'), ('SG워너비', '라라라'), ('카더가든', '가까운 듯 먼 그대여'), ('이예준', '그날에 나는 맘이 편했을까'), ('선우정아', '도망가자 (Run With Me)'), ('SG워너비', '넌 좋은 사람'), ('조이 (JOY)', '좋은 사람 있으면 소개시켜줘'), ('정동하', '추억은 만남보다 이별에 남아'), ('허각', '우린 어쩌다 헤어진 걸까'), ('태연 (TAEYEON)', '사계 (Four Seasons)'), ('Stray Kids (스트레이 키즈)', 'DOMINO'), ('Christopher', 'Bad'), ('PATEKO (파테코)', 'Rainy day (Feat. ASH ISLAND & Skinny Brown)'), ('Lauv', 'Paris In The Rain'), ('김호중', '만개 (Prod. 신지후)'), ('Dua Lipa', "Don't Start Now"), ('숀 (SHAUN)', 'Way Back Home'), ('#안녕', '너의 번호를 누르고 (Prod. by 영화처럼)'), ('Sam Ryder', 'Tiny Riot'), ('백지영 & 이홍기 (FT아일랜드)', '다시 사랑할 수 있을까'), ('방탄소년단', 'ON'), ('노을', '늦은 밤 너의 집 앞 골목길에서'), ('김호중', '나보다 더 사랑해요'), ('Stray Kids (스트레이 키즈)', 'CHEESE ...

# %%
print(dt.now())
for i in range(200):
    print('{0:3d}위 {1} - {2}'.format(i+1, genie[i][0], genie[i][1]))
# Out:
# 2021-09-02 15:38:18.994614
#   1위 케이윌 (K.Will) - 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
#   2위 The Kid LAROI & Justin Bieber - Stay
#   3위 이무진 - 신호등
#   4위 MSG워너비 (M.O.M) - 바라만 본다
#   5위 멜로망스 (MeloMance) - 고백
#   6위 디핵 (D-Hack) & PATEKO - OHAYO MY NIGHT
#   7위 Red Velvet (레드벨벳) - Queendom
#   8위 AKMU (악뮤) - 낙하 (With 아이유)
#   9위 aespa - Next Level
#  10위 Ed Sheeran - Bad Habits
#  11위 태연 (TAEYEON) - Weekend
#  12위 조정석 - 좋아좋아
#  13위 방탄소년단 - Permission to Dance
#  14위 전소미 - DUMB DUMB
#  15위 방탄소년단 - Butter
#  16위 Justin Bieber - Peaches (Feat. Daniel Caesar & Giveon)
#  17위 이무진 - 비와 당신
#  18위 헤이즈 (Heize) - 헤픈 우연
#  19위 헤이즈 (Heize) - 비가 오는 날엔 (2021)
#  20위 방탄소년단 - Dynamite
#  21위 경서예지 & 전건호 - 다정히 내 이름을 부르면
#  22위 브레이브걸스 (Brave girls) - 롤린 (Rollin')
#  23위 아이유 (IU) - 라일락
#  24위 빅마마 (Big Mama) - 하루만 더
#  25위 임영웅 - 이제 나만 믿어요
#  26위 오마이걸 (OH MY GIRL) - Dun Dun Dance
#  27위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  28위 10CM - 고백
#  29위 아이유 (IU) - Celebrity
#  30위 브레이브걸스 (Brave girls) - 치맛바람 (Chi Mat Ba Ram)
#  31위 Jawsh 685 & Jason Derulo & 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  32위 다비치 - 사진을 보다가
#  33위 임영웅 - 다시 사랑한다면 (김필 Ver.)
#  34위 임영웅 - 별빛 같은 나의 사랑아
#  35위 TWICE (트와이스) - Alcohol-Free
#  36위 아이유 (IU) - 내 손을 잡아
#  37위 김대명 - 가을 우체국 앞에서
#  38위 임영웅 - HERO
#  39위 브레이브걸스 (Brave girls) - 운전만해 (We Ride)
#  40위 Justin Bieber - Off My Face
#  41위 Pink Sweat$ - At My Worst
#  42위 조이 (JOY) - 안녕 (Hello)
#  43위 세븐틴 (SEVENTEEN) - 여전히 아름다운지
#  44위 조정석 - 아로하
#  45위 SG워너비 - Timeless
#  46위 호미들 - 사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)
#  47위 라붐 (LABOUM) - 상상더하기
#  48위 Anne-Marie - 2002
#  49위 STAYC (스테이씨) - ASAP
#  50위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  51위 장범준 - 추적이는 여름 비가 되어
#  52위 임영웅 - 그대라는 사치
#  53위 MSG워너비 (정상동기) - 나를 아는 사람
#  54위 etham - 12 : 45 (Stripped)
#  55위 임영웅 - 끝사랑
#  56위 송이한 - 밝게 빛나는 별이 되어 비춰줄게
#  57위 임영웅 - Bk Love
#  58위 Stray Kids (스트레이 키즈) - 소리꾼
#  59위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  60위 아이유 (IU) - Blueming
#  61위 미도와 파라솔 - 이젠 잊기로 해요 (Drama Ver.)
#  62위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
#  63위 아이유 (IU) - 어푸 (Ah puh)
#  64위 아이유 (IU) - 에잇 (Prod. & Feat. SUGA of BTS)
#  65위 임영웅 - 잊었니
#  66위 방탄소년단 - Life Goes On
#  67위 김종국 - 눈물을 훔친다 (금혼령 X 김종국)
#  68위 방탄소년단 - 봄날
#  69위 Doja Cat - Kiss Me More (Feat. SZA)
#  70위 MSG워너비 - 상상더하기
#  71위 양요섭 & 정은지 - LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
#  72위 경서 - 밤하늘의 별을 (2020)
#  73위 ASH ISLAND - 멜로디
#  74위 환희 - 오늘은 가지마 (2021)
#  75위 임영웅 - 미워요
#  76위 규현 (KYUHYUN) - 별이 빛나는 밤에
#  77위 AKMU (악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  78위 미도와 파라솔 - 슈퍼스타
#  79위 Bruno Mars & Anderson .Paak & Silk Sonic - Leave The Door Open
#  80위 임영웅 - 계단말고 엘리베이터
#  81위 BLACKPINK - Lovesick Girls
#  82위 창모 (CHANGMO) - METEOR
#  83위 임영웅 - 사랑의 아픔 딛고
#  84위 장범준 - 나는 너 좋아
#  85위 임영웅 - 목로주점
#  86위 장범준 - 잠이 오질 않네요
#  87위 장범준 - 고백
#  88위 John K - parachute
#  89위 Standing Egg (스탠딩 에그) - 오래된 노래
#  90위 오마이걸 (OH MY GIRL) - Dolphin
#  91위 Maroon 5 - Memories
#  92위 전미도 - 사랑하게 될 줄 알았어
#  93위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#  94위 정경호 - 회상
#  95위 미란이 (Mirani) & 먼치맨 (MUNCHMAN) & Khundi Panda & 머쉬베놈 (MUSHVENOM) - VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)
#  96위 로꼬 & 이성경 - 러브 (Prod. by 로코베리)
#  97위 Tones And I - Dance Monkey
#  98위 미도와 파라솔 - 벌써 일년 (Drama Ver.)
#  99위 경서예지 - 은하수를 닮은 너에게 (Feat. 몰리디)
# 100위 헤이즈 (Heize) - 비도 오고 그래서 (Feat. 신용재)
# 101위 원슈타인 - 밤이 되니까
# 102위 아이유 (IU) - Coin
# 103위 마크툽 (Maktub) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 104위 SG워너비 - 라라라
# 105위 카더가든 - 가까운 듯 먼 그대여
# 106위 이예준 - 그날에 나는 맘이 편했을까
# 107위 선우정아 - 도망가자 (Run With Me)
# 108위 SG워너비 - 넌 좋은 사람
# 109위 조이 (JOY) - 좋은 사람 있으면 소개시켜줘
# 110위 정동하 - 추억은 만남보다 이별에 남아
# 111위 허각 - 우린 어쩌다 헤어진 걸까
# 112위 태연 (TAEYEON) - 사계 (Four Seasons)
# 113위 Stray Kids (스트레이 키즈) - DOMINO
# 114위 Christopher - Bad
# 115위 PATEKO (파테코) - Rainy day (Feat. ASH ISLAND & Skinny Brown)
# 116위 Lauv - Paris In The Rain
# 117위 김호중 - 만개 (Prod. 신지후)
# 118위 Dua Lipa - Don't Start Now
# 119위 숀 (SHAUN) - Way Back Home
# 120위 #안녕 - 너의 번호를 누르고 (Prod. by 영화처럼)
# 121위 Sam Ryder - Tiny Riot
# 122위 백지영 & 이홍기 (FT아일랜드) - 다시 사랑할 수 있을까
# 123위 방탄소년단 - ON
# 124위 노을 - 늦은 밤 너의 집 앞 골목길에서
# 125위 김호중 - 나보다 더 사랑해요
# 126위 Stray Kids (스트레이 키즈) - CHEESE
# 127위 아이유 (IU) - 마음을 드려요
# 128위 오반 (OVAN) - 어떻게 지내 (Prod. by VAN.C)
# 129위 Stray Kids (스트레이 키즈) - The View
# 130위 청하 & Christopher - Bad Boy
# 131위 방탄소년단 - DNA
# 132위 폴킴 - 안녕
# 133위 비투비 - Outsider
# 134위 Stray Kids (스트레이 키즈) - Silent Cry
# 135위 다비치 - 그냥 안아달란 말야
# 136위 Ed Sheeran - Shape Of You
# 137위 Stray Kids (스트레이 키즈) - 말할 수 없는 비밀
# 138위 경서예지 - 사실 나는 (Feat. 전건호)
# 139위 아이유 (IU) - 밤편지
# 140위 Stray Kids (스트레이 키즈) - 씩 (SSICK)
# 141위 우원재 - 시차 (We Are) (Feat. 로꼬 & GRAY)
# 142위 장범준 - 노래방에서
# 143위 Stellar - Ashes
# 144위 Stray Kids (스트레이 키즈) - Gone Away (한 & 승민 & 아이엔)
# 145위 Stray Kids (스트레이 키즈) - 좋아해서 미안
# 146위 오마이걸 (OH MY GIRL) - 살짝 설렜어 (Nonstop)
# 147위 Stray Kids (스트레이 키즈) - Surfin' (리노 & 창빈 & 필릭스)
# 148위 키 (KEY) - Hate that... (Feat. 태연)
# 149위 Stray Kids (스트레이 키즈) - Star Lost
# 150위 성시경 - 너의 모든 순간
# 151위 로제 (ROSE) - On The Ground
# 152위 10CM - 이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)
# 153위 방탄소년단 - 소우주 (Mikrokosmos)
# 154위 Conan Gray - Maniac
# 155위 Stray Kids (스트레이 키즈) - 강박 (방찬 & 현진)
# 156위 헤이즈 (Heize) & 펀치 (Punch) - 밤하늘의 저 별처럼
# 157위 이무진 - 담아 갈게
# 158위 BLACKPINK - How You Like That
# 159위 잔나비 - 주저하는 연인들을 위해
# 160위 오반 (OVAN) - 허리춤
# 161위 Stray Kids (스트레이 키즈) - Back Door
# 162위 폴킴 - 있잖아
# 163위 Stray Kids (스트레이 키즈) - 애
# 164위 폴킴 - 너를 만나
# 165위 호미들 - 사이렌
# 166위 Stray Kids (스트레이 키즈) - WOLFGANG
# 167위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# 168위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 169위 임창정 - 힘든 건 사랑이 아니다
# 170위 로꼬 - 이대로만 (Feat. 죠지)
# 171위 SG워너비 - 내사람 : Partner For Life
# 172위 방탄소년단 - IDOL
# 173위 Marshmello & Jonas Brothers - Leave Before You Love Me
# 174위 Jeremy Zucker - Comethru
# 175위 ITZY (있지) - 마.피.아. In the morning
# 176위 김호중 - 고맙소
# 177위 윤미래 - It's My Life
# 178위 케이시 (Kassy) - 너의 발걸음에 빛을 비춰줄게 (Prod. by 조영수)
# 179위 전상근 - 너무 보고싶어
# 180위 가호 (Gaho) - 시작
# 181위 에일리 (AILEE) - 첫눈처럼 너에게 가겠다
# 182위 방탄소년단 - FAKE LOVE
# 183위 Alan Walker & Noah Cyrus & Digital Farm Animals - All Falls Down (Feat. Juliander)
# 184위 규현 (KYUHYUN) - 화려하지 않은 고백
# 185위 김호중 - 살았소
# 186위 Ariana Grande & Justin Bieber - Stuck With U
# 187위 아이유 (IU) - Love poem
# 188위 Billie Eilish - bad guy
# 189위 유연석 - 너에게
# 190위 Alan Walker & Sabrina Carpenter & Farruko - On My Way
# 191위 백예린 (Yerin Baek) - Square (2017)
# 192위 김호중 - 아무도 잠들지 마라 (Nessun Dorma)
# 193위 멜로망스 (MeloMance) - 선물
# 194위 다비치 - 너에게 못했던 내 마지막 말은
# 195위 aespa - Black Mamba
# 196위 김호중 - 할무니
# 197위 AKMU (악뮤) - 전쟁터 (With 이선희)
# 198위 Ruel - Painkiller
# 199위 허각 - 고백 (바른연애 길잡이 X 허각)
# 200위 이보람 (씨야) - 사랑하니까 (2021)

# %%
# 크롤링한 결과를 텍스트 파일로 저장한다.
#file = open('genieTOP200.txt', 'w')
# 위의 문장처럼 실행했는데 에러가 발생하면 아래와 같이 open() 함수를 수정한다.
file = open('genieTOP200.txt', 'w', -1, 'UTF-8')
file.write('{} 현재 Genie 뮤직 실시간 TOP 100\n'.format(dt.now()))
for i in range(200):
    file.write('{0:3d}위 {1} - {2}\n'.format(i + 1, genie[i][0], genie[i][1]))
file.close()
print('genieTOP200.txt 파일로 쓰기 완료')
# Out:
# genieTOP200.txt 파일로 쓰기 완료

# %%
# 텍스트 파일에 저장된 데이터를 읽어서 화면에 출력한다.
try:
    file = open('genieTOP200.txt', 'r', -1, 'UTF-8')
    lines = file.readlines()
    for line in lines:
        print(line.strip())
    file.close()
    print('genieTOP200.txt 파일에서 읽기 완료')
except FileNotFoundError:
    print('디스크에 genieTOP200.txt 파일이 없습니다.')
# Out:
# 2021-09-02 15:39:03.647486 현재 Genie 뮤직 실시간 TOP 100
# 1위 케이윌 (K.Will) - 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
# 2위 The Kid LAROI & Justin Bieber - Stay
# 3위 이무진 - 신호등
# 4위 MSG워너비 (M.O.M) - 바라만 본다
# 5위 멜로망스 (MeloMance) - 고백
# 6위 디핵 (D-Hack) & PATEKO - OHAYO MY NIGHT
# 7위 Red Velvet (레드벨벳) - Queendom
# 8위 AKMU (악뮤) - 낙하 (With 아이유)
# 9위 aespa - Next Level
# 10위 Ed Sheeran - Bad Habits
# 11위 태연 (TAEYEON) - Weekend
# 12위 조정석 - 좋아좋아
# 13위 방탄소년단 - Permission to Dance
# 14위 전소미 - DUMB DUMB
# 15위 방탄소년단 - Butter
# 16위 Justin Bieber - Peaches (Feat. Daniel Caesar & Giveon)
# 17위 이무진 - 비와 당신
# 18위 헤이즈 (Heize) - 헤픈 우연
# 19위 헤이즈 (Heize) - 비가 오는 날엔 (2021)
# 20위 방탄소년단 - Dynamite
# 21위 경서예지 & 전건호 - 다정히 내 이름을 부르면
# 22위 브레이브걸스 (Brave girls) - 롤린 (Rollin')
# 23위 아이유 (IU) - 라일락
# 24위 빅마마 (Big Mama) - 하루만 더
# 25위 임영웅 - 이제 나만 믿어요
# 26위 오마이걸 (OH MY GIRL) - Dun Dun Dance
# 27위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
# 28위 10CM - 고백
# 29위 아이유 (IU) - Celebrity
# 30위 브레이브걸스 (Brave girls) - 치맛바람 (Chi Mat Ba Ram)
# 31위 Jawsh 685 & Jason Derulo & 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
# 32위 다비치 - 사진을 보다가
# 33위 임영웅 - 다시 사랑한다면 (김필 Ver.)
# 34위 임영웅 - 별빛 같은 나의 사랑아
# 35위 TWICE (트와이스) - Alcohol-Free
# 36위 아이유 (IU) - 내 손을 잡아
# 37위 김대명 - 가을 우체국 앞에서
# 38위 임영웅 - HERO
# 39위 브레이브걸스 (Brave girls) - 운전만해 (We Ride)
# 40위 Justin Bieber - Off My Face
# 41위 Pink Sweat$ - At My Worst
# 42위 조이 (JOY) - 안녕 (Hello)
# 43위 세븐틴 (SEVENTEEN) - 여전히 아름다운지
# 44위 조정석 - 아로하
# 45위 SG워너비 - Timeless
# 46위 호미들 - 사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)
# 47위 라붐 (LABOUM) - 상상더하기
# 48위 Anne-Marie - 2002
# 49위 STAYC (스테이씨) - ASAP
# 50위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 51위 장범준 - 추적이는 여름 비가 되어
# 52위 임영웅 - 그대라는 사치
# 53위 MSG워너비 (정상동기) - 나를 아는 사람
# 54위 etham - 12 : 45 (Stripped)
# 55위 임영웅 - 끝사랑
# 56위 송이한 - 밝게 빛나는 별이 되어 비춰줄게
# 57위 임영웅 - Bk Love
# 58위 Stray Kids (스트레이 키즈) - 소리꾼
# 59위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 60위 아이유 (IU) - Blueming
# 61위 미도와 파라솔 - 이젠 잊기로 해요 (Drama Ver.)
# 62위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
# 63위 아이유 (IU) - 어푸 (Ah puh)
# 64위 아이유 (IU) - 에잇 (Prod. & Feat. SUGA of BTS)
# 65위 임영웅 - 잊었니
# 66위 방탄소년단 - Life Goes On
# 67위 김종국 - 눈물을 훔친다 (금혼령 X 김종국)
# 68위 방탄소년단 - 봄날
# 69위 Doja Cat - Kiss Me More (Feat. SZA)
# 70위 MSG워너비 - 상상더하기
# 71위 양요섭 & 정은지 - LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
# 72위 경서 - 밤하늘의 별을 (2020)
# 73위 ASH ISLAND - 멜로디
# 74위 환희 - 오늘은 가지마 (2021)
# 75위 임영웅 - 미워요
# 76위 규현 (KYUHYUN) - 별이 빛나는 밤에
# 77위 AKMU (악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 78위 미도와 파라솔 - 슈퍼스타
# 79위 Bruno Mars & Anderson .Paak & Silk Sonic - Leave The Door Open
# 80위 임영웅 - 계단말고 엘리베이터
# 81위 BLACKPINK - Lovesick Girls
# 82위 창모 (CHANGMO) - METEOR
# 83위 임영웅 - 사랑의 아픔 딛고
# 84위 장범준 - 나는 너 좋아
# 85위 임영웅 - 목로주점
# 86위 장범준 - 잠이 오질 않네요
# 87위 장범준 - 고백
# 88위 John K - parachute
# 89위 Standing Egg (스탠딩 에그) - 오래된 노래
# 90위 오마이걸 (OH MY GIRL) - Dolphin
# 91위 Maroon 5 - Memories
# 92위 전미도 - 사랑하게 될 줄 알았어
# 93위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
# 94위 정경호 - 회상
# 95위 미란이 (Mirani) & 먼치맨 (MUNCHMAN) & Khundi Panda & 머쉬베놈 (MUSHVENOM) - VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)
# 96위 로꼬 & 이성경 - 러브 (Prod. by 로코베리)
# 97위 Tones And I - Dance Monkey
# 98위 미도와 파라솔 - 벌써 일년 (Drama Ver.)
# 99위 경서예지 - 은하수를 닮은 너에게 (Feat. 몰리디)
# 100위 헤이즈 (Heize) - 비도 오고 그래서 (Feat. 신용재)
# 101위 원슈타인 - 밤이 되니까
# 102위 아이유 (IU) - Coin
# 103위 마크툽 (Maktub) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 104위 SG워너비 - 라라라
# 105위 카더가든 - 가까운 듯 먼 그대여
# 106위 이예준 - 그날에 나는 맘이 편했을까
# 107위 선우정아 - 도망가자 (Run With Me)
# 108위 SG워너비 - 넌 좋은 사람
# 109위 조이 (JOY) - 좋은 사람 있으면 소개시켜줘
# 110위 정동하 - 추억은 만남보다 이별에 남아
# 111위 허각 - 우린 어쩌다 헤어진 걸까
# 112위 태연 (TAEYEON) - 사계 (Four Seasons)
# 113위 Stray Kids (스트레이 키즈) - DOMINO
# 114위 Christopher - Bad
# 115위 PATEKO (파테코) - Rainy day (Feat. ASH ISLAND & Skinny Brown)
# 116위 Lauv - Paris In The Rain
# 117위 김호중 - 만개 (Prod. 신지후)
# 118위 Dua Lipa - Don't Start Now
# 119위 숀 (SHAUN) - Way Back Home
# 120위 #안녕 - 너의 번호를 누르고 (Prod. by 영화처럼)
# 121위 Sam Ryder - Tiny Riot
# 122위 백지영 & 이홍기 (FT아일랜드) - 다시 사랑할 수 있을까
# 123위 방탄소년단 - ON
# 124위 노을 - 늦은 밤 너의 집 앞 골목길에서
# 125위 김호중 - 나보다 더 사랑해요
# 126위 Stray Kids (스트레이 키즈) - CHEESE
# 127위 아이유 (IU) - 마음을 드려요
# 128위 오반 (OVAN) - 어떻게 지내 (Prod. by VAN.C)
# 129위 Stray Kids (스트레이 키즈) - The View
# 130위 청하 & Christopher - Bad Boy
# 131위 방탄소년단 - DNA
# 132위 폴킴 - 안녕
# 133위 비투비 - Outsider
# 134위 Stray Kids (스트레이 키즈) - Silent Cry
# 135위 다비치 - 그냥 안아달란 말야
# 136위 Ed Sheeran - Shape Of You
# 137위 Stray Kids (스트레이 키즈) - 말할 수 없는 비밀
# 138위 경서예지 - 사실 나는 (Feat. 전건호)
# 139위 아이유 (IU) - 밤편지
# 140위 Stray Kids (스트레이 키즈) - 씩 (SSICK)
# 141위 우원재 - 시차 (We Are) (Feat. 로꼬 & GRAY)
# 142위 장범준 - 노래방에서
# 143위 Stellar - Ashes
# 144위 Stray Kids (스트레이 키즈) - Gone Away (한 & 승민 & 아이엔)
# 145위 Stray Kids (스트레이 키즈) - 좋아해서 미안
# 146위 오마이걸 (OH MY GIRL) - 살짝 설렜어 (Nonstop)
# 147위 Stray Kids (스트레이 키즈) - Surfin' (리노 & 창빈 & 필릭스)
# 148위 키 (KEY) - Hate that... (Feat. 태연)
# 149위 Stray Kids (스트레이 키즈) - Star Lost
# 150위 성시경 - 너의 모든 순간
# 151위 로제 (ROSE) - On The Ground
# 152위 10CM - 이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)
# 153위 방탄소년단 - 소우주 (Mikrokosmos)
# 154위 Conan Gray - Maniac
# 155위 Stray Kids (스트레이 키즈) - 강박 (방찬 & 현진)
# 156위 헤이즈 (Heize) & 펀치 (Punch) - 밤하늘의 저 별처럼
# 157위 이무진 - 담아 갈게
# 158위 BLACKPINK - How You Like That
# 159위 잔나비 - 주저하는 연인들을 위해
# 160위 오반 (OVAN) - 허리춤
# 161위 Stray Kids (스트레이 키즈) - Back Door
# 162위 폴킴 - 있잖아
# 163위 Stray Kids (스트레이 키즈) - 애
# 164위 폴킴 - 너를 만나
# 165위 호미들 - 사이렌
# 166위 Stray Kids (스트레이 키즈) - WOLFGANG
# 167위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# 168위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 169위 임창정 - 힘든 건 사랑이 아니다
# 170위 로꼬 - 이대로만 (Feat. 죠지)
# 171위 SG워너비 - 내사람 : Partner For Life
# 172위 방탄소년단 - IDOL
# 173위 Marshmello & Jonas Brothers - Leave Before You Love Me
# 174위 Jeremy Zucker - Comethru
# 175위 ITZY (있지) - 마.피.아. In the morning
# 176위 김호중 - 고맙소
# 177위 윤미래 - It's My Life
# 178위 케이시 (Kassy) - 너의 발걸음에 빛을 비춰줄게 (Prod. by 조영수)
# 179위 전상근 - 너무 보고싶어
# 180위 가호 (Gaho) - 시작
# 181위 에일리 (AILEE) - 첫눈처럼 너에게 가겠다
# 182위 방탄소년단 - FAKE LOVE
# 183위 Alan Walker & Noah Cyrus & Digital Farm Animals - All Falls Down (Feat. Juliander)
# 184위 규현 (KYUHYUN) - 화려하지 않은 고백
# 185위 김호중 - 살았소
# 186위 Ariana Grande & Justin Bieber - Stuck With U
# 187위 아이유 (IU) - Love poem
# 188위 Billie Eilish - bad guy
# 189위 유연석 - 너에게
# 190위 Alan Walker & Sabrina Carpenter & Farruko - On My Way
# 191위 백예린 (Yerin Baek) - Square (2017)
# 192위 김호중 - 아무도 잠들지 마라 (Nessun Dorma)
# 193위 멜로망스 (MeloMance) - 선물
# 194위 다비치 - 너에게 못했던 내 마지막 말은
# 195위 aespa - Black Mamba
# 196위 김호중 - 할무니
# 197위 AKMU (악뮤) - 전쟁터 (With 이선희)
# 198위 Ruel - Painkiller
# 199위 허각 - 고백 (바른연애 길잡이 X 허각)
# 200위 이보람 (씨야) - 사랑하니까 (2021)
# genieTOP200.txt 파일에서 읽기 완료
